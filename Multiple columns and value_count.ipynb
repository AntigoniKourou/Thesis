# %%
# The usual preamble
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

# Make the graphs a bit prettier, and bigger
pd.set_option('display.mpl_style', 'default')

# This is necessary to show lots of columns in pandas 0.12. 
# Not necessary in pandas 0.13.
pd.set_option('display.width', 5000) 
pd.set_option('display.max_columns', 60)

plt.rcParams['figure.figsize'] = (15, 5)
# Out:
# c:\python27\lib\site-packages\IPython\core\interactiveshell.py:2885: FutureWarning:
# mpl_style had been deprecated and will be removed in a future version.
# Use `matplotlib.pyplot.style.use` instead.
#
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
contents=pd.read_csv('C:/Python27/output_first1500.csv')

# %%
contents
# Out:
#         Listing ID  Reviewer ID  Review ID                                           Sentence  Sentiment score  Feature: Accuracy  Feature: Check-in  Feature: Cleanliness  Feature: Communication  Feature: Location  Feature: Value
# 0          1000126      5116283    3943194                            The place is a miracle!         0.623909           0.000000                0.0              0.000000                0.000000           0.623909        0.000000
# 1          1000126      5116283    3943194  I stayed there with my girlfriend for a week a...        -0.273213          -0.000000               -0.0             -0.000000               -0.000000          -0.273213       -0.000000
# 2          1000126      5116283    3943194  Great location, lots of shops and cafes around...         0.937745           0.000000                0.0              0.000000                0.000000           0.937745        0.000000
# ...

# %%
contents[['Listing ID', 'Review ID', 'Sentiment score']][:25]
# Out:
#     Listing ID  Review ID  Sentiment score
# 0      1000126    3943194         0.623909
# 1      1000126    3943194        -0.273213
# 2      1000126    3943194         0.937745
# 3      1000126    3943194         0.440434
# 4      1000126    3943194        -0.169473
# 5      1000126    3943194         0.000000
# 6      1000126    3943194         0.226348
# 7      1000126    4045839         0.895665
# 8      1000126    4045839         0.571885
# 9      1000126    4045839         0.457562
# 10     1000126    4045839         0.599373
# 11     1000126    4253797         0.475428
# 12     1000126    4253797         0.784096
# 13     1000126    4253797         0.493915
# 14     1000126    4253797         0.000000
# 15     1000126    4253797         0.801610
# 16     1000126    4253797         0.585882
# 17     1000126    4253797         0.708927
# 18     1000126    4253797         0.542326
# 19     1000126    4253797         0.000000
# 20     1000126    4253797        -0.571885
# ...

# %%
biggest_reviews = contents['Review ID'].value_counts()
biggest_reviews[:10]
# Out:
# 18532435    41
# 27269730    41
# 22050021    35
# 9437863     33
# 20299196    32
# 37952329    31
# 43477669    31
# 30401026    31
# 9085792     31
# 8446838     30
# Name: Review ID, dtype: int64

# %%
biggest_reviews.plot(kind='bar')

# %%
biggest_reviews = contents['Review ID'].value_counts()
