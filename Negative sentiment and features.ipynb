# %%
# The usual preamble
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Make the graphs a bit prettier, and bigger
pd.set_option('display.mpl_style', 'default')
plt.rcParams['figure.figsize'] = (15, 5)


# This is necessary to show lots of columns in pandas 0.12. 
# Not necessary in pandas 0.13.
pd.set_option('display.width', 5000) 
pd.set_option('display.max_columns', 60)
# Out:
# c:\python27\lib\site-packages\IPython\core\interactiveshell.py:2885: FutureWarning:
# mpl_style had been deprecated and will be removed in a future version.
# Use `matplotlib.pyplot.style.use` instead.
#
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
file = pd.read_csv('C:/Python27/output_first1500.csv')

# %%
# Select the rows with negative sentiment
negative_sentences = file[file['Sentiment score'] < 0]

# %%
# Count the listings with the biggest number of negative sentiment
negative_sentences['Listing ID'].value_counts()[:3]
# Out:
# 193081    66
# 152280    61
# 158466    60
# Name: Listing ID, dtype: int64

# %%
neg_for_top_listing = negative_sentences[negative_sentences['Listing ID'] == 152280]

# %%
neg_for_top_listing
# Out:
#         Listing ID  Reviewer ID  Review ID                                           Sentence  Sentiment score  Feature: Accuracy  Feature: Check-in  Feature: Cleanliness  Feature: Communication  Feature: Location  Feature: Value
# 109438      152280       775027     421320     However we unfortunately didn't meet with Max.        -0.339950          -0.000000          -0.000000             -0.000000                    -0.0          -0.000000       -0.000000
# 109441      152280       839012     426360  Unfortunately we didn't meet Max himself, but ...        -0.177858          -0.000000          -0.000000             -0.000000                    -0.0          -0.000000       -0.000000
# 109470      152280       909454     513355  A few hours after I posted the above, "neutral...        -0.729026          -0.729026          -0.000000             -0.000000                    -0.0          -0.000000       -0.000000
# ...

# %%
negative_sentences['Listing ID'].value_counts()[:10].plot(kind='bar')

# %%
# Find sentences with negative sentences about location
negative_location = negative_sentences[negative_sentences['Feature: Location'] < 0][['Listing ID', 'Review ID', 'Sentence', 'Sentiment score', 'Feature: Location']]

# %%
negative_location
# Out:
#         Listing ID  Review ID                                           Sentence  Sentiment score  Feature: Location
# 1          1000126    3943194  I stayed there with my girlfriend for a week a...        -0.273213          -0.273213
# 4          1000126    3943194  I spent another two weeks in Amsterdam in two ...        -0.169473          -0.056485
# 104        1000126    7179964      I could not recommend a better place to stay.        -0.544769          -0.544769
# 120        1000126    6518496                    You can stay here with no dubt.        -0.295958          -0.295958
# 129        1000126    5888644  But still there is bus stop just in front of h...        -0.526742          -0.526742
# 144        1000252    9003320  Location: Well connected, the bus stop is 5 me...        -0.025811          -0.012906
# 410        1004255    7134456  The place itself only disappointed with soso w...        -0.476658          -0.476658
# ...

# %%
negative_location['Listing ID'].value_counts()[:10].plot(kind='bar')

# %%
neg_listing = negative_location[negative_sentences['Listing ID'] == 118117]
# Out:
# c:\python27\lib\site-packages\ipykernel\__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':

# %%
neg_listing
# Out:
#        Listing ID  Review ID                                           Sentence  Sentiment score  Feature: Location
# 38856      118117     828829  So if you are looking for somewhere to stay th...        -0.025811          -0.025811
# 38883      118117     924315  to the tram stop and then about 10 minutes on ...        -0.295958          -0.295958
# 38957      118117    1382862  It seemed to me that house is located at the v...        -0.349135          -0.349135
# 39001      118117    1910530  I hate to write a bad review for this property...        -0.726946          -0.726946
# 39004      118117    1910530  However, we stayed in Summer and there was no ...        -0.487424          -0.487424
# 39008      118117    1910530  I was in Amsterdam for my birthday and was rea...        -0.525630          -0.525630
# 39019      118117    2087836  Tram stop is just few steps from the building....        -0.295958          -0.295958
# ...

# %%
# The sentiment of negative sentences for the listing which counted more negative sentences
neg_listing['Sentiment score'].plot(kind='bar')
