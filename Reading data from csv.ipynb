# %%
# Render our plots inline
# %matplotlib inline

import pandas as pd
import matplotlib.pyplot as plt

pd.set_option('display.mpl_style', 'default') # Make the graphs a bit prettier
plt.rcParams['figure.figsize'] = (15, 5)

# %%
broken_df = pd.read_csv('C:/Python27/output_first1500.csv')

# %%
broken_df[:5]
# Out:
#    Listing ID  Reviewer ID  Review ID  \
# 0     1000126      5116283    3943194
# 1     1000126      5116283    3943194
# 2     1000126      5116283    3943194
# 3     1000126      5116283    3943194
# 4     1000126      5116283    3943194
#
#                                             Sentence  Sentiment score  \
# 0                            The place is a miracle!         0.623909
# 1  I stayed there with my girlfriend for a week a...        -0.273213
# 2  Great location, lots of shops and cafes around...         0.937745
# 3  I mean you really wanna call this place home a...         0.440434
# 4  I spent another two weeks in Amsterdam in two ...        -0.169473
#
#    Feature: Accuracy  Feature: Check-in  Feature: Cleanliness  \
# 0           0.000000                0.0                   0.0
# 1          -0.000000               -0.0                  -0.0
# 2           0.000000                0.0                   0.0
# 3           0.000000                0.0                   0.0
# 4          -0.056485               -0.0                  -0.0
#
#    Feature: Communication  Feature: Location  Feature: Value
# 0                     0.0           0.623909        0.000000
# 1                    -0.0          -0.273213       -0.000000
# 2                     0.0           0.937745        0.000000
# 3                     0.0           0.440434        0.000000
# 4                    -0.0          -0.056485       -0.056485

# %%
fixed_df = pd.read_csv('C:/Python27/output_first1500.csv', sep=',', encoding='latin1')
fixed_df[:5]
# Out:
#    Listing ID  Reviewer ID  Review ID  \
# 0     1000126      5116283    3943194
# 1     1000126      5116283    3943194
# 2     1000126      5116283    3943194
# 3     1000126      5116283    3943194
# 4     1000126      5116283    3943194
#
#                                             Sentence  Sentiment score  \
# 0                            The place is a miracle!         0.623909
# 1  I stayed there with my girlfriend for a week a...        -0.273213
# 2  Great location, lots of shops and cafes around...         0.937745
# 3  I mean you really wanna call this place home a...         0.440434
# 4  I spent another two weeks in Amsterdam in two ...        -0.169473
#
#    Feature: Accuracy  Feature: Check-in  Feature: Cleanliness  \
# 0           0.000000                0.0                   0.0
# 1          -0.000000               -0.0                  -0.0
# 2           0.000000                0.0                   0.0
# 3           0.000000                0.0                   0.0
# 4          -0.056485               -0.0                  -0.0
#
#    Feature: Communication  Feature: Location  Feature: Value
# 0                     0.0           0.623909        0.000000
# 1                    -0.0          -0.273213       -0.000000
# 2                     0.0           0.937745        0.000000
# 3                     0.0           0.440434        0.000000
# 4                    -0.0          -0.056485       -0.056485

# %%
fixed_df['Sentiment score'].plot()
