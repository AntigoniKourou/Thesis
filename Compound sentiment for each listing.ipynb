# %%
# %matplotlib inline

import pandas as pd
import matplotlib.pyplot as plt


pd.set_option('display.mpl_style', 'default') # Make the graphs a bit prettier
plt.rcParams['figure.figsize'] = (15, 5)
plt.rcParams['font.family'] = 'sans-serif'

# This is necessary to show lots of columns in pandas 0.12. 
# Not necessary in pandas 0.13.
pd.set_option('display.width', 5000) 
pd.set_option('display.max_columns', 60)
# Out:
# c:\python27\lib\site-packages\IPython\core\interactiveshell.py:2885: FutureWarning:
# mpl_style had been deprecated and will be removed in a future version.
# Use `matplotlib.pyplot.style.use` instead.
#
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
file = pd.read_csv('C:/Python27/output_first1500.csv')[['Listing ID','Sentiment score']]

# %%
sent = file[['Sentiment score']].copy()

# %%
# The compound sentiment score for a listing based on all its text comments. 
# The data is grouped by listing ID and then the average is calculated
file.groupby('Listing ID').mean()[:10]
# Out:
#             Sentiment score
# Listing ID
# 102107             0.489293
# 105074             0.461608
# 105546             0.455881
# 107326             0.395370
# 107972             0.493241
# 111108             0.451321
# 112831             0.481194
# 115795             0.434697
# 118097             0.464740
# 118117             0.469660

# %%
file.groupby('Listing ID').mean().plot()

# %%
mean_sent = file.groupby('Listing ID').mean().sort_values(by='Sentiment score')
mean_sent
# Out:
#             Sentiment score
# Listing ID
# 1566167           -0.065510
# 2009458            0.000000
# 1410370            0.000000
# 1700639            0.000000
# 1038403            0.000000
# 1620720            0.000000
# 1784070            0.000000
# 1839235            0.000000
# 1710196            0.113317
# 1125879            0.134117
# 1636415            0.168932
# 1004473            0.178651
# 1833760            0.181958
# 1803390            0.187299
# 1132039            0.192564
# 1357971            0.193804
# 1227125            0.202265
# 1564385            0.206610
# 1481919            0.233499
# 1088413            0.238844
# 1267968            0.239778
# 1760455            0.263872
# 1549458            0.270609
# 1899014            0.276297
# 1783905            0.276577
# 1227164            0.279405
# 1233749            0.281299
# 1260194            0.285731
# 1636010            0.288618
# 1966319            0.290235
# ...                     ...
# ...

# %%
ids = mean_sent[mean_sent['Sentiment score']==0]
ids
# Out:
#             Sentiment score
# Listing ID
# 2009458                 0.0
# 1410370                 0.0
# 1700639                 0.0
# 1038403                 0.0
# 1620720                 0.0
# 1784070                 0.0
# 1839235                 0.0

# %%
answ=ids['Sentiment score'].value_counts()
print 'The number of lisitings which have cancelled is: '
answ
# Out:
# The number of lisitings which have cancelled is:
# 0.0    7
# Name: Sentiment score, dtype: int64

# %%
no_sentiment = pd.read_csv('C:/Python27/output_first1500.csv')[['Listing ID','Review ID', 'Sentence']]
a = [2009458,1410370,1700639,1038403,1620720,1784070,1839235]
for i in a: 
    print no_sentiment[no_sentiment['Listing ID']==i]
    print '\n'
# Out:
#         Listing ID  Review ID                                           Sentence
# 189195     2009458   19584464  The reservation was canceled 34 days before ar...
# 189196     2009458   19584464                      This is an automated posting.
#
#
#        Listing ID  Review ID                                           Sentence
# 90712     1410370   30601951  The reservation was canceled 20 days before ar...
# 90713     1410370   30601951                      This is an automated posting.
#
#
#         Listing ID  Review ID                                           Sentence
# 140442     1700639   31758125  The reservation was canceled 12 days before ar...
# 140443     1700639   31758125                      This is an automated posting.
#
#
#        Listing ID  Review ID                                           Sentence
# 10997     1038403   19183739  The reservation was canceled the day before ar...
# ...
